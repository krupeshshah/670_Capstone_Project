# %% [markdown]
# # First Attempt

# %%
import requests

url = "http://developer.nrel.gov/api/nsrdb/v2/solar/psm3-tmy-download.json?api_key=tAbtm47qhh3NRHrUgBR0IV3FsL04ASCpAOcQeUEw"

# payload = "wkt=POINT(-99.49218%2043.83452)&attributes=dhi%2Cdni%2Cghi%2Cdew_point%2Cair_temperature%2Csurface_pressure%2Cwind_direction%2Cwind_speed%2Csurface_albedo%2C%2C%2C&names=tmy-2017%2Ctdy-2017%2Ctgy-2017&full_name=Krupesh%20Shah&email=ksfrost18@gmai.@company.com&affiliation=NREL&mailing_list=false&reason=test&utc=true"
payload = "wkt=POINT(-99.49218%2043.83452)&attributes=dhi%2Cdni%2Cghi%2Cdew_point%2Cair_temperature%2Csurface_pressure%2Cwind_direction%2Cwind_speed%2Csurface_albedo%2C%2C%2C&names=[\"tmy\",\"tmy-2020\",\"tmy-2019\",\"tmy-2018\",\"tmy-2017\",\"tdy-2020\",\"tdy-2019\",\"tdy-2018\",\"tdy-2017\",\"tgy-2020\",\"tgy-2019\",\"tgy-2018\",\"tgy-2017\"]&full_name=Krupesh+Shah&email=ksfrost18@gmail.com&affiliation=NREL&mailing_list=false&reason=test&utc=true"
headers = {
    'content-type': "application/x-www-form-urlencoded",
    'cache-control': "no-cache"
}

response = requests.request("POST", url, data=payload, headers=headers)

print(response.text)
# Out:
# {"inputs":{"body":{},"params":{},"query":{}},"metadata":{"version":"2.0.0"},"status":400,"errors":["The required 'email' parameter must be a valid email address","The required 'wkt' or 'location_ids' must be a string or any array of integers respectively","The required 'names' parameter must contain a list of comma separated names in the set [\"tmy\",\"tmy-2020\",\"tmy-2019\",\"tmy-2018\",\"tmy-2017\",\"tdy-2020\",\"tdy-2019\",\"tdy-2018\",\"tdy-2017\",\"tgy-2020\",\"tgy-2019\",\"tgy-2018\",\"tgy-2017\"]."]}

# %% [markdown]
# # Second Attempt

# %%
longitude = '-74.047455'
latitude = '40.721568'
region_name = 'Jersey City, New Jersey, United States'

location = {'region_name':'Jersey City'}

# %%
import requests
import pandas as pd

# Define API endpoint and parameters
url = 'https://developer.nrel.gov/api/nsrdb/v2/solar/psm3-tmy.json'
params = {
    'api_key': 'tAbtm47qhh3NRHrUgBR0IV3FsL04ASCpAOcQeUEw',
    'lat': '27.763915',
    'lon': '-98.238895',
    'year': '2020'
}

# Make request to API and convert response to dataframe
response = requests.get(url, params=params)
print(response)
# data = response.json()['outputs']
# df = pd.DataFrame(data)
# print(df)

# # Select solar radiation data and convert units to watts per square meter
# solar_radiation = df['solrad_Avg'] / 1000

# # Calculate average solar radiation
# avg_solar_radiation = solar_radiation.mean()

# # Print the average solar radiation for the year
# print(f'Average solar radiation for Boulder, CO in 2020: {avg_solar_radiation:.2f} W/m^2')
# Out:
# <Response [404]>

# %% [markdown]
# # Need To check code

# %%
# Declare all variables as strings. Spaces must be replaced with '+', i.e., change 'John Smith' to 'John+Smith'.
# Define the lat, long of the location and the year
lat, lon, year = 33.2164, -97.1292, 2020
# You must request an NSRDB api key from the link above
api_key = '{{tAbtm47qhh3NRHrUgBR0IV3FsL04ASCpAOcQeUEw}}'
# Set the attributes to extract (e.g., dhi, ghi, etc.), separated by commas.
attributes = 'ghi,dhi,dni,wind_speed,air_temperature,solar_zenith_angle'
# Choose year of data
year = '2020'
# Set leap year to true or false. True will return leap day data if present, false will not.
leap_year = 'false'
# Set time interval in minutes, i.e., '30' is half hour intervals. Valid intervals are 30 & 60.
interval = '30'
# Specify Coordinated Universal Time (UTC), 'true' will use UTC, 'false' will use the local time zone of the data.
# NOTE: In order to use the NSRDB data in SAM, you must specify UTC as 'false'. SAM requires the data to be in the
# local time zone.
utc = 'false'
# Your full name, use '+' instead of spaces.
your_name = 'Krupesh+Shah'
# Your reason for using the NSRDB.
reason_for_use = 'Edu'
# Your affiliation
your_affiliation = 'SOU'
# Your email address
your_email = 'kshah3@saintperters.edu'
# Please join our mailing list so we can keep you up-to-date on new developments.
mailing_list = 'true'

# Declare url string
url = 'https://developer.nrel.gov/api/nsrdb/v2/solar/psm3-download.csv?wkt=POINT({lon}%20{lat})&names={year}&leap_day={leap}&interval={interval}&utc={utc}&full_name={name}&email={email}&affiliation={affiliation}&mailing_list={mailing_list}&reason={reason}&api_key={api}&attributes={attr}'.format(year=year, lat=lat, lon=lon, leap=leap_year, interval=interval, utc=utc, name=your_name, email=your_email, mailing_list=mailing_list, affiliation=your_affiliation, reason=reason_for_use, api=api_key, attr=attributes)
# Return just the first 2 lines to get metadata:
info = pd.read_csv(url, nrows=1)
# See metadata for specified properties, e.g., timezone and elevation
timezone, elevation = info['Local Time Zone'], info['Elevation']
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File c:\Program Files\Python310\lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File c:\Program Files\Python310\lib\http\client.py:1276, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1275 """Send a complete request to the server."""
# -> 1276 self._send_request(method, url, body, headers, encode_chunked)
#
# File c:\Program Files\Python310\lib\http\client.py:1322, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1321     body = _encode(body, 'body')
# ...

# %%
# # Return all but first 2 lines of csv to get data:
# df = pd.read_csv('https://developer.nrel.gov/api/nsrdb/v2/solar/psm3-download.csv?wkt=POINT({lon}%20{lat})&names={year}&leap_day={leap}&interval={interval}&utc={utc}&full_name={name}&email={email}&affiliation={affiliation}&mailing_list={mailing_list}&reason={reason}&api_key={api}&attributes={attr}'.format(year=year, lat=lat, lon=lon, leap=leap_year, interval=interval, utc=utc, name=your_name, email=your_email, mailing_list=mailing_list, affiliation=your_affiliation, reason=reason_for_use, api=api_key, attr=attributes), skiprows=2)

# # Set the time index in the pandas dataframe:
# df = df.set_index(pd.date_range('1/1/{yr}'.format(yr=year), freq=interval+"Min", periods=525600/int(interval)))

# # take a look
# print("shape:', df.shape)
# df.head()

# %% [markdown]
# # Final Attempt

# %% [markdown]
# ## Making List of Location

# %%
location_dict = {"long_lat":"POINT(-74.047455 40.721568)" ,"region":"Jersey City, New Jersey, United States" }

location = {}
location_list = [] 
location['Jersey_NJ_US'] = location_dict
location_list.append(location_dict)
location_dict = {"long_lat":"POINT(-98.238895 27.763915)" ,"region":"San Diego, Texas, United States" }
location['SanDiego_TX_US'] = location_dict
location_list.append(location_dict)
type(location)
print(location_list)
# Out:
# [{'long_lat': 'POINT(-74.047455 40.721568)', 'region': 'Jersey City, New Jersey, United States'}, {'long_lat': 'POINT(-98.238895 27.763915)', 'region': 'San Diego, Texas, United States'}]

# %% [markdown]
# ## Trying with Single File to get

# %%
import requests
import pandas as pd
import io

# Set the API endpoint URL
url = 'https://developer.nrel.gov/api/solar/nsrdb_psm3_download.csv'
# 'attributes': 'Year, Month, Day, Hour, Minute, DHI, DNI, GHI,Clearsky DHI,Clearsky DNI,Clearsky GHI,Cloud Type,Dew Point,Solar Zenith Angle,Fill Flag,Surface Albedo,Wind Speed, Precipitable Water, Wind Direction,Relative Humidity, Temperature, Pressure'
# Set the query parameters
params = {
    'api_key': 'tAbtm47qhh3NRHrUgBR0IV3FsL04ASCpAOcQeUEw',
    'wkt': 'POINT(-98.238895 27.763915)',
    'names': '2020',
    
    'leap_year': 'false',
    'interval': '60',
    'utc': 'false',
    'full_name': 'true',
    'email': 'ksfrost18@gmai.com'
}

# # Send the API request and get the response data as text
# response = requests.get(url, params=params)
# data = response.text

# # Save the response data as a CSV file using pandas
# df = pd.read_csv(data.splitlines())
# df.to_csv('nsrdb_data.csv', index=False)


# Send the API request and get the response data as bytes
response = requests.get(url, params=params)

df = pd.read_csv(io.StringIO(response.text), skiprows=2)
data_text = response.text
print(response)
data = response.content
print(data)
# Save the response data to a file object
# with open('nsrdb_data1.csv', 'wb') as f:
#     f.write(data)

# # Load the CSV data into a pandas DataFrame
# df = pd.read_csv('nsrdb_data1.csv')
# Out:
# <Response [200]>
# ...

# %%
df
# Out:
#       Year  Month  Day  Hour  Minute  Temperature  Clearsky DHI  Clearsky DNI  \
# 0     2020      1    1     0      30         11.1             0             0
# 1     2020      1    1     1      30         11.2             0             0
# 2     2020      1    1     2      30         11.2             0             0
# 3     2020      1    1     3      30         11.2             0             0
# 4     2020      1    1     4      30         11.2             0             0
# ...    ...    ...  ...   ...     ...          ...           ...           ...
# 8755  2020     12   31    19      30         11.7             0             0
# 8756  2020     12   31    20      30         11.4             0             0
# 8757  2020     12   31    21      30         11.2             0             0
# 8758  2020     12   31    22      30         11.0             0             0
# 8759  2020     12   31    23      30         11.0             0             0
#
# ...

# %% [markdown]
# ## Lib

# %%
import requests
import zipfile
import io
import os
import configparser
import json
import pandas as pd

# %% [markdown]
# ## Working on Multile Data with including json and config

# %%
location_dict = {"long_lat":"POINT(-74.047455 40.721568)" ,"region":"Jersey City, New Jersey, United States" }

location = {}
location_list = [] 
location['Jersey_NJ_US'] = location_dict
location_list.append(location_dict)
location_dict = {"long_lat":"POINT(-98.238895 27.763915)" ,"region":"San Diego, Texas, United States" }
location['SanDiego_TX_US'] = location_dict
location_list.append(location_dict)
type(location)
print(location_list)
# Out:
# [{'long_lat': 'POINT(-74.047455 40.721568)', 'region': 'Jersey City, New Jersey, United States'}, {'long_lat': 'POINT(-98.238895 27.763915)', 'region': 'San Diego, Texas, United States'}]

# %% [markdown]
# ## functiona for reading jsons and config files

# %%
def read_ini_extra(file_path, key):
    config = configparser.ConfigParser()
    config.read(file_path)
    value = config.get('CONSTANT', key, fallback='Key is not defined')
    return value

def read_json(file_path):
    with open(file_path, "r") as f:
        return json.load(f)
    
# read ini file
read_ini_extra(file_path="config.ini",key = 'PATH')
read_ini_extra(file_path="config.ini",key = 'UPDATED_PATH')

# read dict obj
# config_json = read_json(file_path="config.json")
# read_ini_extra(dict_obj=config_json)
# Out:
# 'Key is not defined'

# %%
location_years = read_json(file_path="location.json")
print(location_years['locations'])
print(location_years['years'])
# Out:
# [{'long_lat': 'POINT(-74.047455 40.721568)', 'region': 'Jersey City, New Jersey, United States'}, {'long_lat': 'POINT(-98.238895 27.763915)', 'region': 'San Diego, Texas, United States'}]
# ['2018', '2019', '2020', '2021', '2022']

# %% [markdown]
# ## Reading Config Files

# %%
# Set up API request parameters locally
# url = "https://developer.nrel.gov/api/solar/nsrdb_psm3_download.csv"
# api_key = "tAbtm47qhh3NRHrUgBR0IV3FsL04ASCpAOcQeUEw"
# years = ["2018", "2019", "2020","2021","2022"]
# updated_path = read_ini_extra(file_path="config.ini",key = 'UPDATED_PATH')
# locations = ["POINT(-105.2705 40.0150)", "POINT(-106.6098 35.0844)"]
#attributes = "ghi,dni,dhi,wind_speed,air_temperature,relative_humidity,precipitable_water,solar_zenith_angle"
# attributes = ["Year", "Month", "Day", "Hour", "Minute", "DHI", "DNI", "GHI","Clearsky DHI", "Clearsky DNI", "Clearsky GHI", "Cloud Type","Dew Point", "Solar Zenith Angle", "Fill Flag", "Surface Albedo","Wind Speed", "Precipitable Water", "Wind Direction","Relative Humidity", "Temperature", "Pressure"]
# utc = "false"
# interval = "60"
# email = "ksfrost18@gmail.com"

# %%
config = configparser.ConfigParser()
config.sections()
config.read('config.ini')
config["API"]["API_KEY"]
# Out:
# 'tAbtm47qhh3NRHrUgBR0IV3FsL04ASCpAOcQeUEw'

# %% [markdown]
# ## Getting File through api for mulitple location and years

# %% [markdown]
# ## Crating Location Json for the getting data through api.

# %%
location_years = {
    "locations":
    [
        {
            "long_lat": "POINT(-74.7597 40.2206)",
            "region": "North_New Jersey_Trenton"
        }, 
        {
            "long_lat": "POINT(-97.7431 30.2672)", 
            "region": "South_texas_Austin"
        },
        {
            "long_lat": "POINT(-77.4360 37.5407)", 
            "region": "East_virginia_Richmond"
        },
        {
            "long_lat": "POINT(-121.4944 38.5816)", 
            "region": "West_California_Sacramento"
        },
        {
            "long_lat": "POINT(-80.23825 26.70442)", 
            "region": "Florida, Florida, United States"
        }
    ],
    "years":["2016","2017","2018", "2019", "2020"]
}
location_years
# Out:
# {'locations': [{'long_lat': 'POINT(-74.7597 40.2206)',
#    'region': 'North_New Jersey_Trenton'},
#   {'long_lat': 'POINT(-97.7431 30.2672)', 'region': 'South_texas_Austin'},
#   {'long_lat': 'POINT(-77.4360 37.5407)', 'region': 'East_virginia_Richmond'},
#   {'long_lat': 'POINT(-121.4944 38.5816)',
#    'region': 'West_California_Sacramento'},
#   {'long_lat': 'POINT(-80.23825 26.70442)',
#    'region': 'Florida, Florida, United States'}],
#  'years': ['2016', '2017', '2018', '2019', '2020']}

# %% [markdown]
# # API Call for the getting all the data at a same time.

# %%
# reading data form config files

# location_years = read_json(file_path="location.json")
# Loop through years and locations and download data
for year in location_years['years']:
    for location in location_years['locations']:
        print(location['long_lat'])
        # Set up API request parameters for each location and year
        querystring = {"wkt": location['long_lat'], "names": year, "utc": config["API"]["UTC"], "interval": config["API"]["INTERVAL"], "email": config["API"]["EMAIL"], "api_key": config["API"]["API_KEY"]}

        # Make API request and get response content as bytes
        response = requests.get(config["API"]["URL"], params=querystring)
        df = pd.read_csv(io.StringIO(response.text))
        region_Name  = location['region']
        region_split = region_Name.split(',')
        print(region_split)
        path = f"{year}_{location['region']}.csv"
        updated_path = config["PATHS"]["UPDATED_PATH"] # read_ini_extra(file_path="config.ini",key = 'UPDATED_PATH')
        upload_path = config["PATHS"]["PATH"] # read_ini_extra(file_path="config.ini",key = 'PATH')
        upload_path = f"{upload_path}/raw_api_data/{location['region']}"
        # Check whether the specified path exists or not
        print(updated_path)
        print(upload_path)

        isExist = os.path.exists(upload_path)
        if not isExist:
            # Create a new directory because it does not exist
            os.makedirs(upload_path)
            upload_path = f"{upload_path}/{path}" 
            df.to_csv(upload_path, index=False)

            print(f"The new directory is created! and uploaded file on  {upload_path}")
        else:
            upload_path = f"{upload_path}/{path}" 
            df.to_csv(upload_path, index=False)

            print(f"The new file is uploaded {upload_path}")
# Out:
# POINT(-74.7597 40.2206)
# ['North_New Jersey_Trenton']
# data/updated_data
# data//raw_api_data/North_New Jersey_Trenton
# The new file is uploaded data//raw_api_data/North_New Jersey_Trenton/2016_North_New Jersey_Trenton.csv
# POINT(-97.7431 30.2672)
# ['South_texas_Austin']
# data/updated_data
# data//raw_api_data/South_texas_Austin
# The new file is uploaded data//raw_api_data/South_texas_Austin/2016_South_texas_Austin.csv
# POINT(-77.4360 37.5407)
# ['East_virginia_Richmond']
# data/updated_data
# data//raw_api_data/East_virginia_Richmond
# The new file is uploaded data//raw_api_data/East_virginia_Richmond/2016_East_virginia_Richmond.csv
# POINT(-121.4944 38.5816)
# ['West_California_Sacramento']
# data/updated_data
# data//raw_api_data/West_California_Sacramento
# The new directory is created! and uploaded file on  data//raw_api_data/West_California_Sacramento/2016_West_California_Sacramento.csv
# POINT(-80.23825 26.70442)
# ['Florida', ' Florida', ' United States']
# ...

# %% [markdown]
# ## testing code

# %%
# Code for the get the first letter of each word.
# import re
 
# def name(s):
#   # Use regular expression to extract the first letter of each word
#   initials = re.findall(r'\b\w', s)
#   print(initials)
  
#   # Use regular expression to extract the last word
#   last_name = s.split(',')[-1]
#   # Combine the initials and last name with dots
#   result = '.'.join(initials[:]).upper()
 
#   return result
 
# #Driver code
# s = "mohandas karamchand gandhi"
# print(name(s))
# Out:
# ['m', 'k', 'g']
# M.Mohandas Karamchand Gandhi

# %% [markdown]
# ## Zip file reader but did not work

# %%
   # Extract the ZIP file and save the CSV file
        # with zipfile.ZipFile(io.BytesIO(content)) as myzip:
        #     filename = f"{year}_{location}.csv"
        #     with myzip.open(filename) as myfile:
        #         data = myfile.read()
        #         with open(filename, "wb") as f:
        #             f.write(data)
# Out:
# 'data/'

# %% [markdown]
# # Config file reader code

# %%
import configparser

def read_ini(file_path):
    config = configparser.ConfigParser()
    config.read(file_path)
    for section in config.sections():
        for key in config[section]:
            print((key, config[section][key]))
 
read_ini("config.ini")
# Out:
# ('environment', 'test')
# ('debug', 'True')
# ('username', 'xiaoxu')
# ('password', 'xiaoxu')
# ('host', '127.0.0.1')
# ('port', '5432')
# ('db', 'xiaoxu_database')
# ('path', 'data/')
# ('updated_path', 'data/updated_data')

# %% [markdown]
# # this code is given by the nsrdb for the downloading data.
# but issue with this code is using this code they sending mail for each year data and we have to download the data form email link and unzip and copy to our location.

# %%
import requests
import pandas as pd
import urllib.parse
import time

API_KEY = "tAbtm47qhh3NRHrUgBR0IV3FsL04ASCpAOcQeUEw"
EMAIL = "ksfrost18@gmail.com"
BASE_URL = "https://developer.nrel.gov/api/nsrdb/v2/solar/spectral-ondemand-download.json?"
POINTS = [
'1061419'
]

def main():
    input_data = {
        'interval': '60',
        'equipment': 'one_axis',
        
        'api_key': API_KEY,
        'email': EMAIL,
    }
    for name in ['2018']:
        print(f"Processing name: {name}")
        for id, location_ids in enumerate(POINTS):
            input_data['names'] = [name]
            input_data['location_ids'] = location_ids
            print(f'Making request for point group {id + 1} of {len(POINTS)}...')

            if '.csv' in BASE_URL:
                url = BASE_URL + urllib.parse.urlencode(data, True)
                # Note: CSV format is only supported for single point requests
                # Suggest that you might append to a larger data frame
                data = pd.read_csv(url)
                print(f'Response data (you should replace this print statement with your processing): {data}')
                # You can use the following code to write it to a file
                # data.to_csv('SingleBigDataPoint.csv')
            else:
                headers = {
                  'x-api-key': API_KEY
                }
                data = get_response_json_and_handle_errors(requests.post(BASE_URL, input_data, headers=headers))
                download_url = data['outputs']['downloadUrl']
                # You can do with what you will the download url
                print(data['outputs']['message'])
                print(f"Data can be downloaded from this url when ready: {download_url}")

                # Delay for 1 second to prevent rate limiting
                time.sleep(1)
            print(f'Processed')


def get_response_json_and_handle_errors(response: requests.Response) -> dict:
    """Takes the given response and handles any errors, along with providing
    the resulting json

    Parameters
    ----------
    response : requests.Response
        The response object

    Returns
    -------
    dict
        The resulting json
    """
    if response.status_code != 200:
        print(f"An error has occurred with the server or the request. The request response code/status: {response.status_code} {response.reason}")
        print(f"The response body: {response.text}")
        exit(1)

    try:
        response_json = response.json()
    except:
        print(f"The response couldn't be parsed as JSON, likely an issue with the server, here is the text: {response.text}")
        exit(1)

    if len(response_json['errors']) > 0:
        errors = '\n'.join(response_json['errors'])
        print(f"The request errored out, here are the errors: {errors}")
        exit(1)
    return response_json

if __name__ == "__main__":
    main()
# Out:
# Processing name: 2018
# Making request for point group 1 of 1...
# An error has occurred with the server or the request. The request response code/status: 400 Bad Request
# The response body: {"inputs":{"body":{"interval":"60","equipment":"one_axis","api_key":"tAbtm47qhh3NRHrUgBR0IV3FsL04ASCpAOcQeUEw","email":"ksfrost18@gmail.com","names":"2018","location_ids":"1061419"},"params":{},"query":{}},"metadata":{"version":"2.0.0"},"status":400,"errors":["The required 'wkt' parameter must be a string with a spatial extent formatted as Well Known Text"]}
# The request errored out, here are the errors: The required 'wkt' parameter must be a string with a spatial extent formatted as Well Known Text
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 83
#      80     return response_json
#      82 if __name__ == "__main__":
# ---> 83     main()
#
# ...

# %% [markdown]
# # Calling Class

# %%
from src.nsrdb import NSRDBDataDownloader

nsrdb_down = NSRDBDataDownloader()
location_details = nsrdb_down.read_json(file_path="location.json")
location_details
# Out:
# {'locations': [{'long_lat': 'POINT(-74.047455 40.721568)',
#    'region': 'Jersey City, New Jersey, United States'},
#   {'long_lat': 'POINT(-98.238895 27.763915)',
#    'region': 'San Diego, Texas, United States'}],
#  'years': ['2018', '2019', '2020', '2021', '2022']}

# %%
response = nsrdb_down.get_nsrdb_data(location_details['years'], location_details['locations'])
print(response)
# Out:
# None
